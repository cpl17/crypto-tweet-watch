# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import time
import os
import pprint

# %% [markdown]
# # Data

# %%
project_path = "drive/MyDrive/Colab_Notebooks/Projects/Crypto"

# %%
json_file_names = os.listdir(project_path + "/Data")

# %% [markdown]
# **Example Tweet Object**

# %%
with open(project_path + "/Data/" +  json_file_names[0]) as infile:
    tweets_json = json.load(infile)

# %%
tweet = tweets_json[0]

# %%
pprint.pprint(tweet)
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Mon Nov 08 16:10:21 +0000 2021',
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [{'display_url': 'medium.com/@arker-officia…',
#                         'expanded_url': 'https://medium.com/@arker-official/arker-metaverse-2e417ba05ec1',
#                         'indices': [109, 132],
#                         'url': 'https://t.co/ewiy4qirjB'}],
#               'user_mentions': [{'id': 919873360837926912,
#                                  'id_str': '919873360837926912',
#                                  'indices': [3, 18],
#                                  'name': 'Arker The legend of Ohm',
#                                  'screen_name': 'ArkerCommunity'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'filter_level': 'low',
#  'geo': None,
#  'id': 1457742296263233547,
#  'id_str': '1457742296263233547',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'possibly_sensitive': False,
#  'quote_count': 0,
#  'reply_count': 0,
#  'retweet_count': 0,
#  'retweeted': False,
#  'retweeted_status': {'contributors': None,
#                       'coordinates': None,
#                       'created_at': 'Fri Oct 29 16:52:59 +0000 2021',
#                       'entities': {'hashtags': [{'indices': [114, 121],
#                                                  'text': 'crypto'},
#                                                 {'indices': [122, 132],
#                                                  'text': 'play2earn'},
#                                                 {'indices': [133, 139],
#                                                  'text': 'arker'}],
#                                    'symbols': [],
#                                    'urls': [{'display_url': 'medium.com/@arker-officia…',
#                                              'expanded_url': 'https://medium.com/@arker-official/arker-metaverse-2e417ba05ec1',
#                                              'indices': [89, 112],
#                                              'url': 'https://t.co/ewiy4qirjB'}],
#                                    'user_mentions': []},
#                       'favorite_count': 8559,
#                       'favorited': False,
#                       'filter_level': 'low',
#                       'geo': None,
#                       'id': 1454129145634512897,
#                       'id_str': '1454129145634512897',
#                       'in_reply_to_screen_name': None,
#                       'in_reply_to_status_id': None,
#                       'in_reply_to_status_id_str': None,
#                       'in_reply_to_user_id': None,
#                       'in_reply_to_user_id_str': None,
#                       'is_quote_status': False,
#                       'lang': 'en',
#                       'place': None,
#                       'possibly_sensitive': False,
#                       'quote_count': 4926,
#                       'reply_count': 3605,
#                       'retweet_count': 6349,
#                       'retweeted': False,
#                       'source': '<a href="https://mobile.twitter.com" '
#                                 'rel="nofollow">Twitter Web App</a>',
#                       'text': 'Discover the new metaverse of Arker, start a '
#                               'new adventure full of battles and rewards!\n'
#                               '\n'
#                               'https://t.co/ewiy4qirjB\n'
#                               '\n'
#                               '#crypto #play2earn #arker',
#                       'truncated': False,
#                       'user': {'contributors_enabled': False,
#                                'created_at': 'Mon Oct 16 10:31:14 +0000 2017',
#                                'default_profile': True,
#                                'default_profile_image': False,
#                                'description': 'The Online RPG that rewards you '
#                                               'with cryptocurrency.\n'
#                                               '\n'
#                                               'Telegram Group: '
#                                               'https://t.co/w8VYvYQ5FJ\n'
#                                               'Telegram News: '
#                                               'https://t.co/GpzxZ9J6le\n'
#                                               '\n'
#                                               'Join the conquest of Ohm!',
#                                'favourites_count': 9,
#                                'follow_request_sent': None,
#                                'followers_count': 26263,
#                                'following': None,
#                                'friends_count': 7,
#                                'geo_enabled': False,
#                                'id': 919873360837926912,
#                                'id_str': '919873360837926912',
#                                'is_translator': False,
#                                'lang': None,
#                                'listed_count': 8,
#                                'location': 'Ohm City',
#                                'name': 'Arker The legend of Ohm',
#                                'notifications': None,
#                                'profile_background_color': 'F5F8FA',
#                                'profile_background_image_url': '',
#                                'profile_background_image_url_https': '',
#                                'profile_background_tile': False,
#                                'profile_banner_url': 'https://pbs.twimg.com/profile_banners/919873360837926912/1537370078',
#                                'profile_image_url': 'http://pbs.twimg.com/profile_images/1041291180410130432/FjbLOYou_normal.jpg',
#                                'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1041291180410130432/FjbLOYou_normal.jpg',
#                                'profile_link_color': '1DA1F2',
#                                'profile_sidebar_border_color': 'C0DEED',
#                                'profile_sidebar_fill_color': 'DDEEF6',
#                                'profile_text_color': '333333',
#                                'profile_use_background_image': True,
#                                'protected': False,
#                                'screen_name': 'ArkerCommunity',
#                                'statuses_count': 7,
#                                'time_zone': None,
#                                'translator_type': 'none',
#                                'url': 'https://playarker.com/',
#                                'utc_offset': None,
#                                'verified': False,
#                                'withheld_in_countries': []}},
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'text': 'RT @ArkerCommunity: Discover the new metaverse of Arker, start a new '
#          'adventure full of battles and rewards!\n'
#          '\n'
#          'https://t.co/ewiy4qirjB\n'
#          '\n'
#          '#cryp…',
#  'timestamp_ms': '1636387821628',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Wed May 12 08:32:39 +0000 2021',
#           'default_profile': True,
#           'default_profile_image': False,
#           'description': None,
#           'favourites_count': 623,
#           'follow_request_sent': None,
#           'followers_count': 32,
#           'following': None,
#           'friends_count': 518,
#           'geo_enabled': False,
#           'id': 1392397257148801025,
#           'id_str': '1392397257148801025',
#           'is_translator': False,
#           'lang': None,
#           'listed_count': 1,
#           'location': 'Magelang Utara, Indonesia',
#           'name': 'Faiz',
#           'notifications': None,
#           'profile_background_color': 'F5F8FA',
#           'profile_background_image_url': '',
#           'profile_background_image_url_https': '',
#           'profile_background_tile': False,
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/1451029199251148803/zFASgAHY_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1451029199251148803/zFASgAHY_normal.jpg',
#           'profile_link_color': '1DA1F2',
#           'profile_sidebar_border_color': 'C0DEED',
#           'profile_sidebar_fill_color': 'DDEEF6',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'Faiz_2294',
#           'statuses_count': 1250,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': None,
#           'utc_offset': None,
#           'verified': False,
#           'withheld_in_countries': []}}

# %% [markdown]
# **Helper functions**

# %%
def get_user_info(tweet_obj,sublevel=''):
  """ Function to get relevant information for user, and retweeted_status or quoted
  status (if they exist) """

  f = lambda x: x[sublevel] if sublevel != '' else x
  
  if sublevel != '':
    prefix = sublevel + '-'  
  else:
    prefix = sublevel
      
  tweet_obj[prefix + 'user-screen_name'] = f(tweet_obj)['user']['screen_name']
  tweet_obj[prefix + 'user-created_at'] = f(tweet_obj)['user']['created_at']
  tweet_obj[prefix + 'user-followers_count'] = f(tweet_obj)['user']['followers_count']

# %%
def consolidate_text(tweet_obj,sublevel=''):

  """ Function to get consildate text and extended tweet - full text into one """

  if sublevel == '':

    if 'extended_tweet' in tweet_obj:
      tweet_obj['text'] = tweet_obj['extended_tweet']['full_text'] 

  else:

    if 'extended_tweet' in tweet_obj[sublevel]:
      tweet_obj[sublevel + '-text'] = tweet_obj[sublevel]['extended_tweet']['full_text']      
    else:
      tweet_obj[sublevel + '-text'] = tweet_obj[sublevel]['text']

# %%
def flatten_tweets(tweets_json):
    """ Flattens out tweet dictionaries so relevant JSON
        is in a top-level dictionary."""

    tweets_list = []
    
    
    for tweet in tweets_json:
        # Reorganize User info and text 

        get_user_info(tweet)
        consolidate_text(tweet)     

        # If status is a retweet, reorganize retweeted user info and text
        if 'retweeted_status' in tweet:
          
          get_user_info(tweet,'retweeted_status')
          consolidate_text(tweet,'retweeted_status')
        
       # If status is a quote tweet, reorganize quoted user info and text
        if 'quoted_status' in tweet:

          get_user_info(tweet,'quoted_status')
          consolidate_text(tweet,'quoted_status')
        
        # Geographic location for user
        if 'location' in tweet['user']:

          tweet['user-location'] = tweet['user']['location']

        if 'place' in tweet['user']:

          tweet['user-place'] = tweet['user']['place']

            
        tweets_list.append(tweet)

    return tweets_list

# %% [markdown]
# **Extract relevant information and concatenate into DataFrames**

# %%
list_of_dfs = []

for file in json_file_names:
  with open(project_path + "/Data/" + file) as infile:
    tweets_json = json.load(infile)
    tweets = flatten_tweets(tweets_json)
    tweets_df = pd.DataFrame(tweets)
    list_of_dfs.append(tweets_df)

# %%
tweet_df = pd.concat(list_of_dfs)

# %%
tweet_df.reset_index(drop=True,inplace=True)

# %%
columns = ['created_at', 'id','text','in_reply_to_screen_name','place','quote_count',
       'reply_count', 'retweet_count', 'favorite_count', 'entities','user-screen_name', 'user-created_at', 'user-followers_count',
       'user-location', 'retweeted_status-user-screen_name',
       'retweeted_status-user-created_at',
       'retweeted_status-user-followers_count', 'retweeted_status-text','quoted_status-user-created_at', 'quoted_status-user-followers_count',
       'quoted_status-text']

# %%
tweet_df.columns
# Out:
# Index(['created_at', 'id', 'id_str', 'text', 'source', 'truncated',
#        'in_reply_to_status_id', 'in_reply_to_status_id_str',
#        'in_reply_to_user_id', 'in_reply_to_user_id_str',
#        'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place',
#        'contributors', 'retweeted_status', 'is_quote_status', 'quote_count',
#        'reply_count', 'retweet_count', 'favorite_count', 'entities',
#        'favorited', 'retweeted', 'possibly_sensitive', 'filter_level', 'lang',
#        'timestamp_ms', 'user-screen_name', 'user-created_at',
#        'user-followers_count', 'retweeted_status-text', 'user-location',
#        'quoted_status_id', 'quoted_status_id_str', 'quoted_status',
#        'quoted_status_permalink', 'quoted_status-text', 'display_text_range',
#        'extended_tweet', 'extended_entities'],
#       dtype='object')

# %%
tweet_df = tweet_df[columns]

# %% [markdown]
# **Preliminary Data Quality Ensurance**

# %%
tweet_df.shape
# Out:
# (50000, 21)

# %%
tweet_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 21 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   created_at                             50000 non-null  object
#  1   id                                     50000 non-null  int64
#  2   text                                   50000 non-null  object
#  3   in_reply_to_screen_name                7533 non-null   object
#  4   place                                  82 non-null     object
#  5   quote_count                            50000 non-null  int64
#  6   reply_count                            50000 non-null  int64
#  7   retweet_count                          50000 non-null  int64
#  8   favorite_count                         50000 non-null  int64
#  9   entities                               50000 non-null  object
#  10  user-screen_name                       50000 non-null  object
#  11  user-created_at                        50000 non-null  object
#  12  user-followers_count                   50000 non-null  int64
#  13  user-location                          20856 non-null  object
#  14  retweeted_status-user-screen_name      33627 non-null  object
#  15  retweeted_status-user-created_at       33627 non-null  object
#  16  retweeted_status-user-followers_count  33627 non-null  float64
#  17  retweeted_status-text                  33627 non-null  object
#  18  quoted_status-user-created_at          6829 non-null   object
#  19  quoted_status-user-followers_count     6829 non-null   float64
#  20  quoted_status-text                     6829 non-null   object
# dtypes: float64(2), int64(6), object(13)
# memory usage: 8.0+ MB

# %%
tweet_df.head()
# Out:
#                        created_at  ...                         quoted_status-text
# 0  Mon Nov 08 16:10:21 +0000 2021  ...                                        NaN
# 1  Mon Nov 08 16:10:21 +0000 2021  ...  Crypto cities!\n\nhttps://t.co/mUdpYJSDq0
# 2  Mon Nov 08 16:10:21 +0000 2021  ...                                        NaN
# 3  Mon Nov 08 16:10:21 +0000 2021  ...                                        NaN
# 4  Mon Nov 08 16:10:21 +0000 2021  ...                                        NaN
#
# [5 rows x 21 columns]

# %%
tweet_df.shape
# Out:
# (50000, 21)

# %%
for col in tweet_df:
  if "created_at" in col:
    tweet_df[col] = pd.to_datetime(tweet_df[col])

# %%
tweet_df.to_csv(project_path + '/Data/' + 'tweet_df.csv')
